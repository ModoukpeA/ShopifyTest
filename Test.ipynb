# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd

# %%
data = pd.read_excel("2019 Winter Data Science Intern Challenge Data Set.xlsx")
data
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at
# 0    2017-03-13 12:36:56.190
# ...

# %%
data.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#                created_at
# 0 2017-03-13 12:36:56.190
# 1 2017-03-03 17:38:51.999
# 2 2017-03-14 04:23:55.595
# 3 2017-03-26 12:43:36.649
# 4 2017-03-01 04:35:10.773

# %%
data.columns.tolist()
# Out:
# ['order_id',
#  'shop_id',
#  'user_id',
#  'order_amount',
#  'total_items',
#  'payment_method',
#  'created_at']

# %%
data.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %% [markdown]
# According to the description, it can be inferred that the average of orders value is indeed 3145.13 approximately. But is that exact ? We will check whether the dataset contains null values or outliers that can lead to wrong calculations and interpretations.

# %%
data.shape
# Out:
# (5000, 7)

# %%
data.isnull()
# Out:
#       order_id  shop_id  user_id  order_amount  total_items  payment_method  \
# 0        False    False    False         False        False           False
# 1        False    False    False         False        False           False
# 2        False    False    False         False        False           False
# 3        False    False    False         False        False           False
# 4        False    False    False         False        False           False
# ...        ...      ...      ...           ...          ...             ...
# 4995     False    False    False         False        False           False
# 4996     False    False    False         False        False           False
# 4997     False    False    False         False        False           False
# 4998     False    False    False         False        False           False
# 4999     False    False    False         False        False           False
#
#       created_at
# 0          False
# 1          False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   shop_id         5000 non-null   int64
#  2   user_id         5000 non-null   int64
#  3   order_amount    5000 non-null   int64
#  4   total_items     5000 non-null   int64
#  5   payment_method  5000 non-null   object
#  6   created_at      5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 273.6+ KB

# %% [markdown]
# All the 5000 rows of the dataset are not null.

# %%
data.boxplot()

# %% [markdown]
# As it can be seen on the plot, there is effectively an outlier in the order_amount column.
# The value of this metric is 704000, which is a value very far from others. Before considering it, we need to attentively check why the value is so high and what could explain that raise in the order amount.
